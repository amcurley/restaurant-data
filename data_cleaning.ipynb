# %% [markdown]
# To do:
#
# Why is this being made?
# Providing a seamless experience for the restaurant owner and chef
#
# What data do we need?
# We already have data from toaset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
orders = pd.read_csv('../restaurant-data/data/20201205/OrderDetails.csv')
items = pd.read_csv('../restaurant-data/data/20201205/AllItemsReport.csv')

# %%
# Repeat this process for drinks, food, brunch, dessert

def food_export(data):
    food = data[data['Menu Name'] == 'FOOD Short Rib Stewart']
    food = food[['Menu Item', "Item Qty (incl voids)", 'Net Amount']][2:]
    
    # Anomaly detection and removal
    
    
    return food

# %%
food_export(items)
# Out:
#                         Menu Item  Item Qty (incl voids)  Net Amount
# 303             Charcuterie Board                    2.0        19.0
# 304                 Stef's Burger                    2.0        14.0
# 305             Stuffed Mushrooms                    2.0         8.0
# 306            Artichoke Crab Dip                    3.0        13.0
# 307                       Mussels                    3.0        28.0
# 308                  Bacon & Eggs                    0.0         0.0
# 309      New England Lobster Roll                    1.0        20.0
# 310             J's Caprese Salad                    1.0        12.0
# 311         Cauliflower Tacos (V)                    1.0        10.0
# 312                 Plantain Boat                    1.0        11.0
# 313              Eggplant Sliders                    2.0        10.0
# 314                    Fall Salad                    0.0         0.0
# 315                    Beet Salad                    1.0        10.0
# ...

# %%
items['Menu Name'].unique()
# Out:
# array(['ALL MENUS', 'DRINKS', 'FOOD Short Rib Stewart', nan, 'BRUNCH',
#        'DESSERT', 'HAPPY HOUR', 'New Years', 'Special Event',
#        'Valentines Day', 'Restaurant Week', 'Brunch Special',
#        "Mother's Day", 'Gift Cards', 'Open Items'], dtype=object)

# %%
items[['Menu Name', 'Menu Item', "Item Qty (incl voids)"]]
# Out:
#       Menu Name   Menu Item  Item Qty (incl voids)
# 0     ALL MENUS         NaN                  109.0
# 1        DRINKS         NaN                   45.0
# 2        DRINKS         NaN                    6.0
# 3        DRINKS       Pepsi                    0.0
# 4        DRINKS  Diet Pepsi                    0.0
# ..          ...         ...                    ...
# 457  Gift Cards         NaN                    0.0
# 458  Open Items         NaN                    0.0
# 459  Open Items         NaN                    0.0
# 460  Open Items         NaN                    0.0
# 461  Open Items         NaN                    0.0
#
# [462 rows x 3 columns]

# %%
items['Menu Name'].unique()
# Out:
# array(['ALL MENUS', 'DRINKS', 'FOOD Short Rib Stewart', nan, 'BRUNCH',
#        'DESSERT', 'HAPPY HOUR', 'New Years', 'Special Event',
#        'Valentines Day', 'Restaurant Week', 'Brunch Special',
#        "Mother's Day", 'Gift Cards', 'Open Items'], dtype=object)

# %%
food = items[items['Menu Name'] == 'FOOD Short Rib Stewart']

# %%
food = food[['Menu Item', "Item Qty (incl voids)", 'Net Amount']][2:]

# %%
plt.figure(figsize=(16, 14))
plt.bar(x=food['Menu Item'],
        height=food["Item Qty (incl voids)"]);
plt.xticks(rotation=45);
