# %%
import pandas as pd
import numpy as np

# %%
orders = pd.read_csv('../restaurant-data/data/20201203/OrderDetails.csv')
items = pd.read_csv('../restaurant-data/data/20201203/AllItemsReport.csv')

# %%
orders.shape
# Out:
# (11, 24)

# %%
items.columns
# Out:
# Index(['Master ID', 'Item ID', 'Parent ID', 'Menu Name', 'Menu Group',
#        'Subgroup', 'Menu Item', 'Avg Price', 'Item Qty (incl voids)',
#        '% of Ttl Qty (incl voids)', 'Gross Amount (incl voids)',
#        '% of Ttl Amt (incl voids)', 'Item Qty', 'Gross Amount', 'Void Qty',
#        'Void Amount', 'Discount Amount', 'Net Amount', '# Orders',
#        '% of Ttl # Orders', '% Qty (Group)', '% Qty (Menu)', '% Qty (All)',
#        '% Net Amt (Group)', '% Net Amt (Menu)', '% Net Amt (All)'],
#       dtype='object')

# %%
items
# Out:
#         Master ID       Item ID     Parent ID   Menu Name   Menu Group  \
# 0             NaN           NaN           NaN   ALL MENUS          NaN
# 1             NaN           NaN           NaN      DRINKS          NaN
# 2    2.000000e+17  2.000000e+17           NaN      DRINKS       Drinks
# 3    2.000000e+17  2.000000e+17  2.000000e+17      DRINKS       Drinks
# 4    2.000000e+17  2.000000e+17  2.000000e+17      DRINKS       Drinks
# ..            ...           ...           ...         ...          ...
# 455  0.000000e+00  0.000000e+00 -1.000000e+00  Gift Cards   Gift Cards
# 456           NaN           NaN           NaN  Open Items          NaN
# 457 -2.000000e+17 -2.000000e+17           NaN  Open Items    Open Food
# 458 -2.000000e+17 -2.000000e+17           NaN  Open Items  Open Liquor
# 459 -2.000000e+17 -2.000000e+17           NaN  Open Items    Open Beer
#
#     Subgroup          Menu Item  Avg Price  Item Qty (incl voids)  \
# ...

# %%
items['Menu Name'].unique()
# Out:
# array(['ALL MENUS', 'DRINKS', 'FOOD Short Rib Stewart', nan, 'BRUNCH',
#        'DESSERT', 'HAPPY HOUR', 'New Years', 'Special Event',
#        'Valentines Day', 'Restaurant Week', 'Brunch Special',
#        "Mother's Day", 'Gift Cards', 'Open Items'], dtype=object)

# %%
items[['Menu Name', 'Menu Item', "Item Qty (incl voids)"]]
# Out:
#       Menu Name          Menu Item  Item Qty (incl voids)
# 0     ALL MENUS                NaN                   57.0
# 1        DRINKS                NaN                   32.0
# 2        DRINKS                NaN                    2.0
# 3        DRINKS              Pepsi                    0.0
# 4        DRINKS         Diet Pepsi                    0.0
# ..          ...                ...                    ...
# 455  Gift Cards  Classic Gift Card                    2.0
# 456  Open Items                NaN                    0.0
# 457  Open Items                NaN                    0.0
# 458  Open Items                NaN                    0.0
# 459  Open Items                NaN                    0.0
#
# [460 rows x 3 columns]

# %%
items['Menu Name'].unique()
# Out:
# array(['ALL MENUS', 'DRINKS', 'FOOD Short Rib Stewart', nan, 'BRUNCH',
#        'DESSERT', 'HAPPY HOUR', 'New Years', 'Special Event',
#        'Valentines Day', 'Restaurant Week', 'Brunch Special',
#        "Mother's Day", 'Gift Cards', 'Open Items'], dtype=object)

# %%
food = items[items['Menu Name'] == 'FOOD Short Rib Stewart']

# %%
food
# Out:
#         Master ID       Item ID     Parent ID               Menu Name  \
# 300           NaN           NaN           NaN  FOOD Short Rib Stewart
# 301  2.000000e+17  2.000000e+17           NaN  FOOD Short Rib Stewart
# 302  2.000000e+17  2.000000e+17  2.000000e+17  FOOD Short Rib Stewart
# 303  2.000000e+17  2.000000e+17  2.000000e+17  FOOD Short Rib Stewart
# 304  2.000000e+17  2.000000e+17  2.000000e+17  FOOD Short Rib Stewart
# 305  2.000000e+17  2.000000e+17  2.000000e+17  FOOD Short Rib Stewart
# 306  2.000000e+17  2.000000e+17  2.000000e+17  FOOD Short Rib Stewart
# 307  2.000000e+17  2.000000e+17  2.000000e+17  FOOD Short Rib Stewart
# 308  2.000000e+17  2.000000e+17  2.000000e+17  FOOD Short Rib Stewart
# 309  2.000000e+17  2.000000e+17  2.000000e+17  FOOD Short Rib Stewart
# 310  2.000000e+17  2.000000e+17  2.000000e+17  FOOD Short Rib Stewart
# 311  2.000000e+17  2.000000e+17  2.000000e+17  FOOD Short Rib Stewart
# ...

# %%
items[['Menu Item', 'Item Qty (incl voids)']]
# Out:
#              Menu Item  Item Qty (incl voids)
# 0                  NaN                   57.0
# 1                  NaN                   32.0
# 2                  NaN                    2.0
# 3                Pepsi                    0.0
# 4           Diet Pepsi                    0.0
# ..                 ...                    ...
# 455  Classic Gift Card                    2.0
# 456                NaN                    0.0
# 457                NaN                    0.0
# 458                NaN                    0.0
# 459                NaN                    0.0
#
# [460 rows x 2 columns]
